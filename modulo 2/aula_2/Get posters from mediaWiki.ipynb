# %%
import pandas as pd
import wptools
import os
import requests
from PIL import Image
from io import BytesIO

# %%
title_list = [
 'The_Wizard_of_Oz_(1939_film)',
 'Citizen_Kane',
 'The_Third_Man',
 'Get_Out_(film)',
 'Mad_Max:_Fury_Road',
 'The_Cabinet_of_Dr._Caligari',
 'All_About_Eve',
 'Inside_Out_(2015_film)',
 'The_Godfather',
 'Metropolis_(1927_film)',
 'E.T._the_Extra-Terrestrial',
 'Modern_Times_(film)',
 'It_Happened_One_Night',
 "Singin'_in_the_Rain",
 'Boyhood_(film)',
 'Casablanca_(film)',
 'Moonlight_(2016_film)',
 'Psycho_(1960_film)',
 'Laura_(1944_film)',
 'Nosferatu',
 'Snow_White_and_the_Seven_Dwarfs_(1937_film)',
 "A_Hard_Day%27s_Night_(film)",
 'La_Grande_Illusion',
 'North_by_Northwest',
 'The_Battle_of_Algiers',
 'Dunkirk_(2017_film)',
 'The_Maltese_Falcon_(1941_film)',
 'Repulsion_(film)',
 '12_Years_a_Slave_(film)',
 'Gravity_(2013_film)',
 'Sunset_Boulevard_(film)',
 'King_Kong_(1933_film)',
 'Spotlight_(film)',
 'The_Adventures_of_Robin_Hood',
 'Rashomon',
 'Rear_Window',
 'Selma_(film)',
 'Taxi_Driver',
 'Toy_Story_3',
 'Argo_(2012_film)',
 'Toy_Story_2',
 'The_Big_Sick',
 'Bride_of_Frankenstein',
 'Zootopia',
 'M_(1931_film)',
 'Wonder_Woman_(2017_film)',
 'The_Philadelphia_Story_(film)',
 'Alien_(film)',
 'Bicycle_Thieves',
 'Seven_Samurai',
 'The_Treasure_of_the_Sierra_Madre_(film)',
 'Up_(2009_film)',
 '12_Angry_Men_(1957_film)',
 'The_400_Blows',
 'Logan_(film)',
 'All_Quiet_on_the_Western_Front_(1930_film)',
 'Army_of_Shadows',
 'Arrival_(film)',
 'Baby_Driver',
 'A_Streetcar_Named_Desire_(1951_film)',
 'The_Night_of_the_Hunter_(film)',
 'Star_Wars:_The_Force_Awakens',
 'Manchester_by_the_Sea_(film)',
 'Dr._Strangelove',
 'Frankenstein_(1931_film)',
 'Vertigo_(film)',
 'The_Dark_Knight_(film)',
 'Touch_of_Evil',
 'The_Babadook',
 'The_Conformist_(film)',
 'Rebecca_(1940_film)',
 "Rosemary%27s_Baby_(film)",
 'Finding_Nemo',
 'Brooklyn_(film)',
 'The_Wrestler_(2008_film)',
 'The_39_Steps_(1935_film)',
 'L.A._Confidential_(film)',
 'Gone_with_the_Wind_(film)',
 'The_Good,_the_Bad_and_the_Ugly',
 'Skyfall',
 'Rome,_Open_City',
 'Tokyo_Story',
 'Hell_or_High_Water_(film)',
 'Pinocchio_(1940_film)',
 'The_Jungle_Book_(2016_film)',
 'La_La_Land_(film)',
 'Star_Trek_(film)',
 'High_Noon',
 'Apocalypse_Now',
 'On_the_Waterfront',
 'The_Wages_of_Fear',
 'The_Last_Picture_Show',
 'Harry_Potter_and_the_Deathly_Hallows_–_Part_2',
 'The_Grapes_of_Wrath_(film)',
 'Roman_Holiday',
 'Man_on_Wire',
 'Jaws_(film)',
 'Toy_Story',
 'The_Godfather_Part_II',
 'Battleship_Potemkin'
]

# %%
folder_name = 'bestofrt_posters'
# Make directory if it doesn't already exist
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %% [markdown]
# #### Note: the cell below, if correctly implemented, will likely take ~5 minutes to run.

# %%
# List of dictionaries to build and convert to a DataFrame later
df_list = []
image_errors = {}
for title in title_list:
    try:
        # This cell is slow so print ranking to gauge time remaining
        ranking = title_list.index(title) + 1
        print(ranking)
        print(title)
        page = wptools.page(title).get()
        # Your code here (three lines)
        images = page.data['image']
        # First image is usually the poster
        first_image_url = images[0]['url']
        print(first_image_url)
        r = requests.get(first_image_url)
        # Download movie poster image
        i = Image.open(BytesIO(r.content))
        image_file_format = first_image_url.split('.')[-1]
        i.save(folder_name + "/" + str(ranking) + "_" + title + '.' + image_file_format)
        # Append to list of dictionaries
        df_list.append({'ranking': int(ranking),
                        'title': title,
                        'poster_url': first_image_url})
    
    # Not best practice to catch all exceptions but fine for this short script
    except Exception as e:
        print(str(ranking) + "_" + title + ": " + str(e))
        image_errors[str(ranking) + "_" + title] = images
# Out:
# 1
# The_Wizard_of_Oz_(1939_film)
# en.wikipedia.org (query) The_Wizard_of_Oz_(1939_film)
# en.wikipedia.org (query) The Wizard of Oz (1939 film) (&plcontinu...
# en.wikipedia.org (parse) 561315
# www.wikidata.org (wikidata) Q193695
# www.wikidata.org (labels) Q6759802|P910|Q1097348|P2747|Q958000|P4...
# www.wikidata.org (labels) P577|Q642196|Q920018|P162|Q16258851|P26...
# www.wikidata.org (labels) Q179200|Q95111|P4276|Q506161|Q11424|P14...
# www.wikidata.org (labels) P1712|Q4343793|P1874|Q3897558|P646|P373...
# en.wikipedia.org (restbase) /page/summary/The_Wizard_of_Oz_(1939_film)
# en.wikipedia.org (imageinfo) File:WIZARD OF OZ ORIGINAL POSTER 19...
# The Wizard of Oz (1939 film) (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(1)> Wizard of Oz
#   assessments: <dict(4)> United States, Film, Library of Congress, Oz
#   claims: <dict(80)> P31, P345, P373, P57, P144, P480, P58, P162, ...
#   description: 1939 movie based on the book by L. Frank Baum
#   exhtml: <str(639)> <p><i><b>The Wizard of Oz</b></i> is a 1939 A...
#   exrest: <str(611)> The Wizard of Oz is a 1939 American musical f...
#   extext: <str(2258)> _**The Wizard of Oz**_ is a 1939 American mu...
#   extract: <str(2368)> <p class="mw-empty-elt"> </p><p><i><b>The W...
#   image: <list(8)> {'kind': 'query-pageimage', 'file': 'File:WIZAR...
#   infobox: <dict(19)> name, image, caption, director, producer, sc...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:T...
#   label: The Wizard of Oz
#   labels: <dict(159)> Q6759802, P910, Q1097348, P2747, Q958000, P4...
#   length: 98,611
#   links: <list(671)> "Live" at the London Palladium, 12th Academy ...
#   modified: <dict(2)> page, wikidata
#   pageid: 561315
#   parsetree: <str(116749)> <root><template><title>short descriptio...
#   random: Hyposmocoma albifrontella
#   redirects: <list(26)> {'pageid': 62130, 'ns': 0, 'title': 'The W...
#   requests: <list(10)> query, query, parse, wikidata, labels, labe...
#   title: The_Wizard_of_Oz_(1939_film)
#   url: https://en.wikipedia.org/wiki/The_Wizard_of_Oz_(1939_film)
#   url_raw: <str(69)> https://en.wikipedia.org/wiki/The_Wizard_of_O...
#   watchers: 582
#   what: film
#   wikibase: Q193695
#   wikidata: <dict(80)> instance of (P31), IMDb ID (P345), Commons ...
#   wikidata_pageid: 191702
#   wikidata_url: https://www.wikidata.org/wiki/Q193695
#   wikitext: <str(97952)> {{short description|1939 movie based on t...
# }
# https://upload.wikimedia.org/wikipedia/commons/c/ca/WIZARD_OF_OZ_ORIGINAL_POSTER_1939.jpg
# 2
# Citizen_Kane
# en.wikipedia.org (query) Citizen_Kane
# en.wikipedia.org (query) Citizen Kane (&plcontinue=5224|0|None_bu...
# en.wikipedia.org (parse) 5224
# www.wikidata.org (wikidata) Q24815
# www.wikidata.org (labels) P910|P1431|P1922|P2747|P4947|P2631|Q130...
# www.wikidata.org (labels) P162|P444|Q2958529|P3219|P268|P344|P263...
# www.wikidata.org (labels) Q1860|Q20644796|Q60|Q12912091|Q1439141|...
# www.wikidata.org (labels) P3808
# en.wikipedia.org (restbase) /page/summary/Citizen_Kane
# en.wikipedia.org (imageinfo) File:Citizen Kane-1.JPG|File:Citizen...
# Citizen Kane (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(4)> United States, Film, Guild of Copy Editor...
#   claims: <dict(97)> P57, P345, P373, P58, P161, P344, P272, P31, ...
#   description: 1941 American drama film directed by Orson Welles
#   exhtml: <str(838)> <p><i><b>Citizen Kane</b></i> is a 1941 Ameri...
#   exrest: <str(792)> Citizen Kane is a 1941 American mystery drama...
#   extext: <str(2519)> _**Citizen Kane**_ is a 1941 American myster...
#   extract: <str(2647)> <p class="mw-empty-elt"></p><p><i><b>Citize...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:Citizenka...
#   infobox: <dict(19)> name, image, alt, caption, director, produce...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/category:C...
#   label: Citizen Kane
#   labels: <dict(151)> P910, P1431, P1922, P2747, P4947, P2631, Q13...
#   length: 206,373
#   links: <list(889)> 14th Academy Awards, 1914 Kentucky Derby, 194...
#   modified: <dict(2)> page, wikidata
#   pageid: 5224
#   parsetree: <str(280315)> <root><template><title>good article</ti...
#   random: Mobjack Bay
#   redirects: <list(11)> {'pageid': 225269, 'ns': 0, 'title': 'Citz...
#   requests: <list(10)> query, query, parse, wikidata, labels, labe...
#   title: Citizen_Kane
#   url: https://en.wikipedia.org/wiki/Citizen_Kane
#   url_raw: https://en.wikipedia.org/wiki/Citizen_Kane?action=raw
#   watchers: 382
#   what: film
#   wikibase: Q24815
#   wikidata: <dict(97)> director (P57), IMDb ID (P345), Commons cat...
#   wikidata_pageid: 28213
#   wikidata_url: https://www.wikidata.org/wiki/Q24815
#   wikitext: <str(205337)> {{good article}}{{Use mdy dates|date=May...
# }
# https://upload.wikimedia.org/wikipedia/en/c/ce/Citizenkane.jpg
# 3
# The_Third_Man
# en.wikipedia.org (query) The_Third_Man
# en.wikipedia.org (query) The Third Man (&plcontinue=71473|0|The_S...
# en.wikipedia.org (parse) 71473
# www.wikidata.org (wikidata) Q271830
# www.wikidata.org (labels) Q45213|Q106940|P1922|Q92072|Q844804|P49...
# www.wikidata.org (labels) P344|P2638|Q89877|P3145|Q1334296|P5786|...
# www.wikidata.org (labels) Q1200678|P272|Q87192|P571|P2465|P2755|P...
# en.wikipedia.org (restbase) /page/summary/The_Third_Man
# en.wikipedia.org (imageinfo) File:Der dritte Mann Logo 001.png|Fi...
# The Third Man (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(3)> Third Man, The 3rd Man, 3rd Man
#   assessments: <dict(5)> Austria, Film, Books, United Kingdom, Vienna
#   claims: <dict(86)> P57, P58, P162, P161, P344, P272, P345, P31, ...
#   description: 1949 film by Carol Reed
#   exhtml: <str(508)> <p><i><b>The Third Man</b></i> is a 1949 Brit...
#   exrest: <str(487)> The Third Man is a 1949 British film noir dir...
#   extext: <str(1532)> _**The Third Man**_ is a 1949 British film n...
#   extract: <str(1630)> <p class="mw-empty-elt"></p><p><i><b>The Th...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:ThirdManU...
#   infobox: <dict(18)> name, image, caption, director, producer, sc...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:T...
#   label: The Third Man
#   labels: <dict(136)> Q45213, Q106940, P1922, Q92072, Q844804, P49...
#   length: 45,802
#   links: <list(603)> 1940s in film, 1950 in music, 21 Days, 4 Mont...
#   modified: <dict(2)> page, wikidata
#   pageid: 71473
#   parsetree: <str(56858)> <root><template><title>About</title><par...
#   random: 1965 Los Angeles Dodgers season
#   redirects: <list(9)> {'pageid': 490410, 'ns': 0, 'title': 'Harry...
#   requests: <list(9)> query, query, parse, wikidata, labels, label...
#   title: The_Third_Man
#   url: https://en.wikipedia.org/wiki/The_Third_Man
#   url_raw: https://en.wikipedia.org/wiki/The_Third_Man?action=raw
#   watchers: 176
#   what: film
#   wikibase: Q271830
#   wikidata: <dict(86)> director (P57), screenwriter (P58), produce...
#   wikidata_pageid: 263053
#   wikidata_url: https://www.wikidata.org/wiki/Q271830
#   wikitext: <str(45463)> {{About|the film}}{{EngvarB|date=Septembe...
# }
# https://upload.wikimedia.org/wikipedia/en/2/21/ThirdManUSPoster.jpg
# 4
# Get_Out_(film)
# en.wikipedia.org (query) Get_Out_(film)
# en.wikipedia.org (parse) 48526729
# www.wikidata.org (wikidata) Q25136235
# www.wikidata.org (labels) P4947|P2631|Q28812610|P750|Q920607|P125...
# www.wikidata.org (labels) Q4550895|P1237|P4632|P905|P31|Q27915576...
# www.wikidata.org (labels) P2603|P2363|P3933|Q47498336|P1411|Q2200...
# en.wikipedia.org (restbase) /page/summary/Get_Out
# en.wikipedia.org (imageinfo) File:Get Out poster.png
# Get Out (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(3)> United States, Film, Horror
#   claims: <dict(72)> P31, P495, P57, P58, P345, P856, P2671, P462,...
#   description: 2017 horror film directed by Jordan Peele
#   exhtml: <str(379)> <p><i><b>Get Out</b></i> is a 2017 American s...
#   exrest: <str(358)> Get Out is a 2017 American satirical horror f...
#   extext: <str(1144)> _**Get Out**_ is a 2017 American satirical h...
#   extract: <str(1224)> <p class="mw-empty-elt"></p><p><i><b>Get Ou...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Get Out p...
#   infobox: <dict(17)> image, caption, director, producer, writer, ...
#   iwlinks: <list(1)> https://en.wikiquote.org/wiki/Get_Out_(film)
#   label: Get Out
#   labels: <dict(118)> P4947, P2631, Q28812610, P750, Q920607, P125...
#   length: 51,726
#   links: <list(336)> (I've Had) The Time of My Life, 12 Years a Sl...
#   modified: <dict(2)> page, wikidata
#   pageid: 48526729
#   parsetree: <str(62593)> <root><template><title>about</title><par...
#   random: Sayeed Hassan Kanan
#   redirected: <list(1)> {'from': 'Get Out (film)', 'to': 'Get Out'}
#   redirects: <list(12)> {'pageid': 55587555, 'ns': 0, 'title': 'Ge...
#   requests: <list(8)> query, parse, wikidata, labels, labels, labe...
#   title: Get_Out
#   url: https://en.wikipedia.org/wiki/Get_Out
#   url_raw: https://en.wikipedia.org/wiki/Get_Out?action=raw
#   watchers: 170
#   what: film
#   wikibase: Q25136235
#   wikidata: <dict(72)> instance of (P31), country of origin (P495)...
#   wikidata_pageid: 27095412
#   wikidata_url: https://www.wikidata.org/wiki/Q25136235
#   wikitext: <str(51293)> {{about|the film|other uses|Get Out (disa...
# }
# https://upload.wikimedia.org/wikipedia/en/a/a3/Get_Out_poster.png
# 5
# Mad_Max:_Fury_Road
# en.wikipedia.org (query) Mad_Max:_Fury_Road
# en.wikipedia.org (query) Mad Max: Fury Road (&plcontinue=36426373...
# en.wikipedia.org (parse) 36426373
# www.wikidata.org (wikidata) Q1757288
# www.wikidata.org (labels) Q1097348|P1431|Q16935134|Q6389652|P4947...
# www.wikidata.org (labels) P2756|Q5799862|P86|Q229390|P1476|Q73246...
# www.wikidata.org (labels) P2529|Q1860|Q1030|Q3130|Q5112210|Q44696...
# www.wikidata.org (labels) P646|P373|P495|Q4960985|Q319221
# en.wikipedia.org (restbase) /page/summary/Mad_Max:_Fury_Road
# en.wikipedia.org (imageinfo) File:Mad Max Fury Road.jpg
# Mad Max: Fury Road (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(3)> Mad Max 4, Fury Road, Mad Max Fury Road
#   assessments: <dict(3)> Australia, Film, Science Fiction
#   claims: <dict(79)> P345, P31, P57, P58, P344, P495, P646, P136, ...
#   description: <str(70)> 2015 Australian post-apocalyptic action f...
#   exhtml: <str(838)> <p><i><b>Mad Max: Fury Road</b></i> is a 2015...
#   exrest: <str(797)> Mad Max: Fury Road is a 2015 post-apocalyptic...
#   extext: <str(2407)> _**Mad Max: Fury Road**_ is a 2015 post-apoc...
#   extract: <str(2519)> <p class="mw-empty-elt"></p><p><i><b>Mad Ma...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Mad Max F...
#   infobox: <dict(19)> name, image, alt, caption, director, produce...
#   iwlinks: <list(1)> https://en.wikiquote.org/wiki/Special:Search/...
#   label: Mad Max: Fury Road
#   labels: <dict(155)> Q1097348, P1431, Q16935134, Q6389652, P4947,...
#   length: 93,383
#   links: <list(598)> /Film, 12 Years a Slave (film), 2000X, 2015 C...
#   modified: <dict(2)> page, wikidata
#   pageid: 36426373
#   parsetree: <str(110770)> <root><template><title>Use Australian E...
#   random: Terra: The Nature of Our World
#   redirects: <list(39)> {'pageid': 468229, 'ns': 0, 'title': 'Mad ...
#   requests: <list(10)> query, query, parse, wikidata, labels, labe...
#   title: Mad_Max:_Fury_Road
#   url: https://en.wikipedia.org/wiki/Mad_Max:_Fury_Road
#   url_raw: https://en.wikipedia.org/wiki/Mad_Max:_Fury_Road?action=raw
#   watchers: 221
#   what: 3D film
#   wikibase: Q1757288
#   wikidata: <dict(79)> IMDb ID (P345), instance of (P31), director...
#   wikidata_pageid: 1689906
#   wikidata_url: https://www.wikidata.org/wiki/Q1757288
#   wikitext: <str(93058)> {{Use Australian English|date=June 2011}}...
# }
# https://upload.wikimedia.org/wikipedia/en/6/6e/Mad_Max_Fury_Road.jpg
# 6
# The_Cabinet_of_Dr._Caligari
# en.wikipedia.org (query) The_Cabinet_of_Dr._Caligari
# en.wikipedia.org (query) The Cabinet of Dr. Caligari (&plcontinue...
# en.wikipedia.org (parse) 173650
# www.wikidata.org (wikidata) Q153886
# www.wikidata.org (labels) Q87651|P4947|P2631|P750|P1258|Q4597156|...
# www.wikidata.org (labels) P57|Q76552|P3593|Q100338|Q2484376|P1970...
# en.wikipedia.org (restbase) /page/summary/The_Cabinet_of_Dr._Caligari
# en.wikipedia.org (imageinfo) File:Das Cabinet des Dr. Caligari.JP...
# The Cabinet of Dr. Caligari (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(1)> Cabinet of Dr. Caligari
#   assessments: <dict(3)> Film, Germany, Horror
#   claims: <dict(70)> P724, P373, P345, P57, P161, P480, P162, P58,...
#   description: 1920 film by Robert Wiene
#   exhtml: <str(542)> <p><i><b>The Cabinet of Dr. Caligari</b></i> ...
#   exrest: <str(521)> The Cabinet of Dr. Caligari is a 1920 German ...
#   extext: <str(1949)> _**The Cabinet of Dr. Caligari**_ ( **German...
#   extract: <str(2051)> <p class="mw-empty-elt"></p><p><i><b>The Ca...
#   image: <list(8)> {'kind': 'query-pageimage', 'file': 'File:Das C...
#   infobox: <dict(14)> name, image, caption, director, producer, wr...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:D...
#   label: The Cabinet of Dr. Caligari
#   labels: <dict(95)> Q87651, P4947, P2631, P750, P1258, Q4597156, ...
#   length: 123,881
#   links: <list(694)> 4K resolution, A Night in Venice (1934 film),...
#   modified: <dict(2)> page, wikidata
#   pageid: 173650
#   parsetree: <str(177730)> <root><template><title>About</title><pa...
#   random: Brow Head
#   redirects: <list(24)> {'pageid': 492265, 'ns': 0, 'title': 'The ...
#   requests: <list(8)> query, query, parse, wikidata, labels, label...
#   title: The_Cabinet_of_Dr._Caligari
#   url: https://en.wikipedia.org/wiki/The_Cabinet_of_Dr._Caligari
#   url_raw: <str(68)> https://en.wikipedia.org/wiki/The_Cabinet_of_...
#   watchers: 146
#   what: film
#   wikibase: Q153886
#   wikidata: <dict(70)> Internet Archive ID (P724), Commons categor...
#   wikidata_pageid: 155268
#   wikidata_url: https://www.wikidata.org/wiki/Q153886
#   wikitext: <str(123401)> {{About|the 1920 film|other uses|The Cab...
# }
# https://upload.wikimedia.org/wikipedia/commons/5/52/Das_Cabinet_des_Dr._Caligari.JPG
# 7
# All_About_Eve
# en.wikipedia.org (query) All_About_Eve
# en.wikipedia.org (query) All About Eve (&plcontinue=41881|0|The_H...
# en.wikipedia.org (parse) 41881
# www.wikidata.org (wikidata) Q200299
# www.wikidata.org (labels) Q20644795|Q474943|Q106301|Q779|P4947|P2...
# www.wikidata.org (labels) P344|P2638|P5786|Q51583|P1562|P3302|P15...
# www.wikidata.org (labels) P3844|Q21995139|Q103360|Q452236|P4786|P...
# en.wikipedia.org (restbase) /page/summary/All_About_Eve
# en.wikipedia.org (imageinfo) File:Bette Davis and Gary Merrill in...
# All About Eve (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(3)> United States, Film, Library of Congress
#   claims: <dict(77)> P57, P162, P161, P31, P344, P58, P373, P345, ...
#   description: 1950 film by Joseph L. Mankiewicz
#   exhtml: <str(259)> <p><i><b>All About Eve</b></i> is a 1950 Amer...
#   exrest: <str(238)> All About Eve is a 1950 American drama film w...
#   extext: <str(1240)> _**All About Eve**_ is a 1950 American drama...
#   extract: <str(1333)> <p class="mw-empty-elt"></p><p><i><b>All Ab...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:AllAboutE...
#   infobox: <dict(19)> name, image, caption, director, producer, sc...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:A...
#   label: All About Eve
#   labels: <dict(130)> Q20644795, Q474943, Q106301, Q779, P4947, P2...
#   length: 47,557
#   links: <list(636)> 12 Years a Slave (film), 1951 Cannes Film Fes...
#   modified: <dict(2)> page, wikidata
#   pageid: 41881
#   parsetree: <str(56803)> <root><template><title>about</title><par...
#   random: Santa Ana, Santa Fe
#   redirects: <list(7)> {'pageid': 900916, 'ns': 0, 'title': 'Eve C...
#   requests: <list(9)> query, query, parse, wikidata, labels, label...
#   title: All_About_Eve
#   url: https://en.wikipedia.org/wiki/All_About_Eve
#   url_raw: https://en.wikipedia.org/wiki/All_About_Eve?action=raw
#   watchers: 95
#   what: film
#   wikibase: Q200299
#   wikidata: <dict(77)> director (P57), producer (P162), cast membe...
#   wikidata_pageid: 197134
#   wikidata_url: https://www.wikidata.org/wiki/Q200299
#   wikitext: <str(47152)> {{about|the film}}{{Use mdy dates|date=De...
# }
# https://upload.wikimedia.org/wikipedia/en/2/22/AllAboutEve.jpeg
# 8
# Inside_Out_(2015_film)
# en.wikipedia.org (query) Inside_Out_(2015_film)
# en.wikipedia.org (parse) 38751266
# www.wikidata.org (wikidata) Q6144664
# www.wikidata.org (labels) P1431|Q155124|P4947|P2631|Q130232|P3212...
# www.wikidata.org (labels) P2554|P577|P4783|P3141|P4933|P162|P3145...
# www.wikidata.org (labels) P58|Q27915574|Q204854|Q859369|P272|P311...
# en.wikipedia.org (restbase) /page/summary/Inside_Out_(2015_film)
# en.wikipedia.org (imageinfo) File:Inside Out (2015 film) poster.jpg
# Inside Out (2015 film) (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(1)> Inside Out 2015
#   assessments: <dict(4)> Film, Animation, Comedy, Disney
#   claims: <dict(96)> P31, P345, P1258, P136, P57, P364, P272, P58,...
#   description: 2015 American animated film produced by Pixar
#   exhtml: <str(619)> <p><i><b>Inside Out</b></i> is a 2015 America...
#   exrest: <str(598)> Inside Out is a 2015 American 3D computer-ani...
#   extext: <str(1898)> _**Inside Out**_ is a 2015 American 3D compu...
#   extract: <str(1995)> <p class="mw-empty-elt"></p><p><i><b>Inside...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Inside Ou...
#   infobox: <dict(20)> name, image, alt, caption, director, produce...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:I...
#   label: Inside Out
#   labels: <dict(147)> P1431, Q155124, P4947, P2631, Q130232, P3212...
#   length: 85,414
#   links: <list(411)> 2015 Cannes Film Festival, 2015 in film, 3D f...
#   modified: <dict(2)> page, wikidata
#   pageid: 38751266
#   parsetree: <str(108339)> <root><template><title>good article</ti...
#   random: Vice Versa
#   redirects: <list(13)> {'pageid': 40038211, 'ns': 0, 'title': 'Th...
#   requests: <list(8)> query, parse, wikidata, labels, labels, labe...
#   title: Inside_Out_(2015_film)
#   url: https://en.wikipedia.org/wiki/Inside_Out_(2015_film)
#   url_raw: https://en.wikipedia.org/wiki/Inside_Out_(2015_film)?ac...
#   watchers: 198
#   what: animated feature film
#   wikibase: Q6144664
#   wikidata: <dict(96)> instance of (P31), IMDb ID (P345), Rotten T...
#   wikidata_pageid: 5938948
#   wikidata_url: https://www.wikidata.org/wiki/Q6144664
#   wikitext: <str(84994)> {{good article}}{{Use American English|da...
# }
# https://upload.wikimedia.org/wikipedia/en/0/0a/Inside_Out_%282015_film%29_poster.jpg
# 9
# The_Godfather
# en.wikipedia.org (query) The_Godfather
# en.wikipedia.org (query) The Godfather (&plcontinue=2466773|0|The...
# en.wikipedia.org (parse) 2466773
# www.wikidata.org (wikidata) Q47703
# www.wikidata.org (labels) P910|P1431|Q95043|P2631|Q130232|P3212|P...
# www.wikidata.org (labels) Q464714|Q214066|Q734043|Q102642|P1476|Q...
# www.wikidata.org (labels) Q296177|P1877|P2130|Q280490|Q318220|P19...
# www.wikidata.org (labels) Q16575211|Q243556|Q7444356|P6145|Q82342...
# en.wikipedia.org (restbase) /page/summary/The_Godfather
# en.wikipedia.org (imageinfo) File:The Godfather.png|File:Godfathe...
# The Godfather (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(2)> Godfather, The Godfather Part I
#   assessments: <dict(6)> United States, New York City, Film, Libra...
#   claims: <dict(96)> P364, P345, P179, P31, P57, P58, P161, P144, ...
#   description: 1972 US film directed by Francis Ford Coppola
#   exhtml: <str(494)> <p><i><b>The Godfather</b></i> is a 1972 Amer...
#   exrest: <str(473)> The Godfather is a 1972 American crime film d...
#   extext: <str(1849)> _**The Godfather**_ is a 1972 American crime...
#   extract: <str(1954)> <p class="mw-empty-elt"></p><p><i><b>The Go...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:Godfather...
#   infobox: <dict(20)> name, image, alt, caption, director, produce...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:T...
#   label: The Godfather
#   labels: <dict(178)> P910, P1431, Q95043, P2631, Q130232, P3212, ...
#   length: 113,274
#   links: <list(546)> 12 Years a Slave (film), 15th Grammy Awards, ...
#   modified: <dict(2)> page, wikidata
#   pageid: 2466773
#   parsetree: <str(174807)> <root><template><title>About</title><pa...
#   random: Harrison Eiteljorg
#   redirects: <list(26)> {'pageid': 1880548, 'ns': 0, 'title': 'The...
#   requests: <list(10)> query, query, parse, wikidata, labels, labe...
#   title: The_Godfather
#   url: https://en.wikipedia.org/wiki/The_Godfather
#   url_raw: https://en.wikipedia.org/wiki/The_Godfather?action=raw
#   watchers: 461
#   what: film
#   wikibase: Q47703
#   wikidata: <dict(96)> original language of film or TV show (P364)...
#   wikidata_pageid: 49812
#   wikidata_url: https://www.wikidata.org/wiki/Q47703
#   wikitext: <str(112760)> {{About|the 1972 film|the original novel...
# }
# https://upload.wikimedia.org/wikipedia/en/1/1c/Godfather_ver1.jpg
# 10
# Metropolis_(1927_film)
# en.wikipedia.org (query) Metropolis_(1927_film)
# en.wikipedia.org (parse) 49696
# www.wikidata.org (wikidata) Q151599
# www.wikidata.org (labels) P2581|P910|Q96469|P4947|P2631|Q130232|P...
# www.wikidata.org (labels) P2638|P5786|Q60528|P3135|P1562|P3302|P1...
# www.wikidata.org (labels) P724|Q15303608|P272|P950|P2465|Q157394|...
# en.wikipedia.org (restbase) /page/summary/Metropolis_(1927_film)
# en.wikipedia.org (imageinfo) File:Metropolisposter.jpg|File:Maria...
# Metropolis (1927 film) (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(3)> Film, Germany, Science Fiction
#   claims: <dict(89)> P724, P373, P57, P58, P162, P161, P344, P345,...
#   description: <str(69)> 1927 German Expressionist science fiction...
#   exhtml: <str(547)> <p><i><b>Metropolis</b></i> is a 1927 German ...
#   exrest: <str(526)> Metropolis is a 1927 German expressionist sci...
#   extext: <str(2507)> _**Metropolis**_ is a 1927 German expression...
#   extract: <str(2633)> <p class="mw-empty-elt"></p><p><i><b>Metrop...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:Metropoli...
#   infobox: <dict(18)> name, image, caption, director, producer, sc...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:M...
#   label: Metropolis
#   labels: <dict(131)> P2581, P910, Q96469, P4947, P2631, Q130232, ...
#   length: 76,639
#   links: <list(377)> 1927 in science fiction, 2011 Adelaide Film F...
#   modified: <dict(2)> page, wikidata
#   pageid: 49696
#   parsetree: <str(105441)> <root><template><title>short descriptio...
#   random: Notice (album)
#   redirects: <list(2)> {'pageid': 2341202, 'ns': 0, 'title': 'Metr...
#   requests: <list(8)> query, parse, wikidata, labels, labels, labe...
#   title: Metropolis_(1927_film)
#   url: https://en.wikipedia.org/wiki/Metropolis_(1927_film)
#   url_raw: https://en.wikipedia.org/wiki/Metropolis_(1927_film)?ac...
#   watchers: 298
#   what: film
#   wikibase: Q151599
#   wikidata: <dict(89)> Internet Archive ID (P724), Commons categor...
#   wikidata_pageid: 153013
#   wikidata_url: https://www.wikidata.org/wiki/Q151599
#   wikitext: <str(76161)> {{short description|1927 German Expressio...
# }
# https://upload.wikimedia.org/wikipedia/en/0/06/Metropolisposter.jpg
# 11
# E.T._the_Extra-Terrestrial
# en.wikipedia.org (query) E.T._the_Extra-Terrestrial
# en.wikipedia.org (parse) 73441
# www.wikidata.org (wikidata) Q11621
# www.wikidata.org (labels) P910|P1431|Q20644795|P4947|P2631|Q13023...
# www.wikidata.org (labels) Q8555|Q374540|P1476|Q464522|Q354873|P57...
# www.wikidata.org (labels) P18|Q849124|P166|P5357|P725|Q1044183|P3...
# www.wikidata.org (labels) Q471839|Q499789|P3107|P3933|P1411|P2509...
# en.wikipedia.org (restbase) /page/summary/E.T._the_Extra-Terrestrial
# en.wikipedia.org (imageinfo) File:E t the extra terrestrial ver3....
# E.T. the Extra-Terrestrial (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(2)> E.T., ET
#   assessments: <dict(4)> United States, Film, Science Fiction, Lib...
#   claims: <dict(94)> P1562, P57, P272, P345, P31, P161, P373, P480...
#   description: <str(63)> 1982 American science fiction film direct...
#   exhtml: <str(570)> <p><i><b>E.T. the Extra-Terrestrial</b></i> i...
#   exrest: <str(549)> E.T. the Extra-Terrestrial is a 1982 American...
#   extext: <str(1731)> _**E.T. the Extra-Terrestrial**_ is a 1982 A...
#   extract: <str(1849)> <p class="mw-empty-elt"></p><p><i><b>E.T. t...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:E t the e...
#   infobox: <dict(18)> name, image, caption, director, producers, w...
#   iwlinks: <list(6)> https://commons.wikimedia.org/wiki/Category:E...
#   label: E.T. the Extra-Terrestrial
#   labels: <dict(174)> P910, P1431, Q20644795, P4947, P2631, Q13023...
#   length: 80,040
#   links: <list(463)> 12 Monkeys, 12 Years a Slave (film), 1941 (fi...
#   modified: <dict(2)> page, wikidata
#   pageid: 73441
#   parsetree: <str(99969)> <root><template><title>Redirect</title><...
#   random: Butler railway station
#   redirects: <list(38)> {'pageid': 177061, 'ns': 0, 'title': 'E.T....
#   requests: <list(9)> query, parse, wikidata, labels, labels, labe...
#   title: E.T._the_Extra-Terrestrial
#   url: https://en.wikipedia.org/wiki/E.T._the_Extra-Terrestrial
#   url_raw: <str(67)> https://en.wikipedia.org/wiki/E.T._the_Extra-...
#   watchers: 290
#   what: film
#   wikibase: Q11621
#   wikidata: <dict(94)> AllMovie movie ID (P1562), director (P57), ...
#   wikidata_pageid: 13150
#   wikidata_url: https://www.wikidata.org/wiki/Q11621
#   wikitext: <str(79731)> {{Redirect|E.T.|other uses|ET (disambigua...
# }
# https://upload.wikimedia.org/wikipedia/en/6/66/E_t_the_extra_terrestrial_ver3.jpg
# 12
# Modern_Times_(film)
# en.wikipedia.org (query) Modern_Times_(film)
# en.wikipedia.org (parse) 74962
# www.wikidata.org (wikidata) Q45602
# www.wikidata.org (labels) Q20644795|P4947|P2631|P750|P1258|P480|Q...
# www.wikidata.org (labels) Q2006459|Q6105016|P915|P269|P57|Q107069...
# en.wikipedia.org (restbase) /page/summary/Modern_Times_(film)
# en.wikipedia.org (imageinfo) File:Modern Times poster.jpg
# Modern Times (film) (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(4)> United States, Film, Comedy, Library of C...
#   claims: <dict(60)> P345, P57, P373, P480, P364, P58, P161, P344,...
#   description: 1936 comedy film by Charles Chaplin
#   exhtml: <str(501)> <p><b>Modern Times</b> is a 1936 American com...
#   exrest: <str(487)> Modern Times is a 1936 American comedy film w...
#   extext: <str(736)> **Modern Times** is a 1936 American comedy fi...
#   extract: <str(795)> <p class="mw-empty-elt"></p><p><b>Modern Tim...
#   image: <list(6)> {'kind': 'query-pageimage', 'file': 'File:Moder...
#   infobox: <dict(15)> name, image, director, producer, writer, sta...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:M...
#   label: Modern Times
#   labels: <dict(92)> Q20644795, P4947, P2631, P750, P1258, P480, Q...
#   length: 19,586
#   links: <list(162)> 2003 Cannes Film Festival, A Burlesque on Car...
#   modified: <dict(2)> page, wikidata
#   pageid: 74962
#   parsetree: <str(23110)> <root><template><title>Use mdy dates</ti...
#   random: Samuel R. Webster
#   redirects: <list(1)> {'pageid': 38710334, 'ns': 0, 'title': 'MOD...
#   requests: <list(7)> query, parse, wikidata, labels, labels, rest...
#   title: Modern_Times_(film)
#   url: https://en.wikipedia.org/wiki/Modern_Times_(film)
#   url_raw: https://en.wikipedia.org/wiki/Modern_Times_(film)?action=raw
#   watchers: 87
#   what: silent film
#   wikibase: Q45602
#   wikidata: <dict(60)> IMDb ID (P345), director (P57), Commons cat...
#   wikidata_pageid: 47765
#   wikidata_url: https://www.wikidata.org/wiki/Q45602
#   wikitext: <str(19400)> {{Use mdy dates|date=June 2013}}{{Infobox...
# }
# https://upload.wikimedia.org/wikipedia/commons/3/36/Modern_Times_poster.jpg
# 13
# It_Happened_One_Night
# en.wikipedia.org (query) It_Happened_One_Night
# en.wikipedia.org (parse) 44696
# www.wikidata.org (wikidata) Q208632
# www.wikidata.org (labels) Q4019932|Q438865|Q186941|P4947|P2631|P3...
# www.wikidata.org (labels) Q505114|P3302|P1552|P345|Q45171911|Q107...
# www.wikidata.org (labels) P2518|Q17308880|P3844|Q960230|Q203819|Q...
# en.wikipedia.org (restbase) /page/summary/It_Happened_One_Night
# en.wikipedia.org (imageinfo) File:Claudette Colbert in It Happene...
# It Happened One Night (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(5)> United States, Film, Comedy, Romance, Lib...
#   claims: <dict(75)> P31, P86, P57, P162, P161, P344, P345, P373, ...
#   description: 1934 film by Frank Capra
#   exhtml: <str(713)> <p><i><b>It Happened One Night</b></i> is a 1...
#   exrest: <str(685)> It Happened One Night is a 1934 pre-Code Amer...
#   extext: <str(1220)> _**It Happened One Night**_ is a 1934 pre-Co...
#   extract: <str(1307)> <p class="mw-empty-elt"></p><p><i><b>It Hap...
#   image: <list(6)> {'kind': 'query-pageimage', 'file': 'File:It-ha...
#   infobox: <dict(19)> name, image, caption, director, producer, sc...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:I...
#   label: It Happened One Night
#   labels: <dict(125)> Q4019932, Q438865, Q186941, P4947, P2631, P3...
#   length: 33,359
#   links: <list(371)> 12 Years a Slave (film), 4K resolution, 7th A...
#   modified: <dict(2)> page, wikidata
#   pageid: 44696
#   parsetree: <str(43001)> <root><template><title>About</title><par...
#   random: Jal el Dib
#   redirects: <list(2)> {'pageid': 5083183, 'ns': 0, 'title': 'It h...
#   requests: <list(8)> query, parse, wikidata, labels, labels, labe...
#   title: It_Happened_One_Night
#   url: https://en.wikipedia.org/wiki/It_Happened_One_Night
#   url_raw: https://en.wikipedia.org/wiki/It_Happened_One_Night?act...
#   watchers: 101
#   what: film
#   wikibase: Q208632
#   wikidata: <dict(75)> instance of (P31), composer (P86), director...
#   wikidata_pageid: 204598
#   wikidata_url: https://www.wikidata.org/wiki/Q208632
#   wikitext: <str(33099)> {{About||the album by Holly Cole|It Happe...
# }
# https://upload.wikimedia.org/wikipedia/commons/d/dc/It-happened-one-night-poster.jpg
# 14
# Singin'_in_the_Rain
# en.wikipedia.org (query) Singin'_in_the_Rain
# en.wikipedia.org (parse) 1883157
# www.wikidata.org (wikidata) Q309153
# www.wikidata.org (labels) Q474943|Q1252302|Q106301|P4947|P2631|P7...
# www.wikidata.org (labels) P1552|P345|Q45171911|Q17126013|P4632|Q2...
# www.wikidata.org (labels) P4665|P6145|Q823422|P2363|Q1282487|P260...
# en.wikipedia.org (restbase) /page/summary/Singin'_in_the_Rain
# en.wikipedia.org (imageinfo) File:Singin' in the Rain trailer.jpg...
# Singin' in the Rain (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(3)> United States, Film, Library of Congress
#   claims: <dict(80)> P345, P373, P31, P57, P161, P364, P480, P162,...
#   description: 1952 American musical comedy film
#   exhtml: <str(372)> <p><i><b>Singin' in the Rain</b></i> is a 195...
#   exrest: <str(351)> Singin' in the Rain is a 1952 American musica...
#   extext: <str(1393)> _**Singin' in the Rain**_ is a 1952 American...
#   extract: <str(1445)> <p><i><b>Singin' in the Rain</b></i> is a 1...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:Singing i...
#   infobox: <dict(20)> name, image, image_size, caption, director, ...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:S...
#   label: Singin' in the Rain
#   labels: <dict(122)> Q474943, Q1252302, Q106301, P4947, P2631, P7...
#   length: 45,437
#   links: <list(312)> 2001: A Space Odyssey (film), 8½, A Guide for...
#   modified: <dict(2)> page, wikidata
#   pageid: 1883157
#   parsetree: <str(59290)> <root><template><title>about</title><par...
#   random: All I Need to Know
#   redirects: <list(11)> {'pageid': 27985, 'ns': 0, 'title': 'Singi...
#   requests: <list(8)> query, parse, wikidata, labels, labels, labe...
#   title: Singin'_in_the_Rain
#   url: https://en.wikipedia.org/wiki/Singin'_in_the_Rain
#   url_raw: https://en.wikipedia.org/wiki/Singin'_in_the_Rain?action=raw
#   watchers: 144
#   what: film
#   wikibase: Q309153
#   wikidata: <dict(80)> IMDb ID (P345), Commons category (P373), in...
#   wikidata_pageid: 297467
#   wikidata_url: https://www.wikidata.org/wiki/Q309153
#   wikitext: <str(45121)> {{about|the film|the song sung in this fi...
# }
# https://upload.wikimedia.org/wikipedia/en/f/f9/Singing_in_the_rain_poster.jpg
# 15
# Boyhood_(film)
# en.wikipedia.org (query) Boyhood_(film)
# en.wikipedia.org (query) Boyhood (film) (&plcontinue=11055577|0|T...
# en.wikipedia.org (parse) 11055577
# www.wikidata.org (wikidata) Q4103201
# www.wikidata.org (labels) P1431|Q106301|Q40035|P2631|Q130232|P494...
# www.wikidata.org (labels) P3302|P1552|P345|Q45171911|P1237|P4632|...
# en.wikipedia.org (restbase) /page/summary/Boyhood_(film)
# en.wikipedia.org (imageinfo) File:Boyhood-logo.svg|File:Boyhood (...
# Boyhood (film) (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(3)> United States, Film, Houston
#   claims: <dict(63)> P345, P31, P57, P161, P646, P1265, P1258, P57...
#   description: <str(68)> 2014 American coming-of-age drama film di...
#   exhtml: <str(455)> <p><i><b>Boyhood</b></i> is a 2014 American e...
#   exrest: <str(427)> Boyhood is a 2014 American epic coming-of-age...
#   extext: <str(1525)> _**Boyhood**_ is a 2014 American epic coming...
#   extract: <str(1611)> <p class="mw-empty-elt"></p><p><i><b>Boyhoo...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:Boyhood (...
#   infobox: <dict(17)> name, image, caption, director, producer, wr...
#   iwlinks: <list(2)> https://en.wikiquote.org/wiki/Special:Search/...
#   label: Boyhood
#   labels: <dict(99)> P1431, Q106301, Q40035, P2631, Q130232, P4947...
#   length: 52,012
#   links: <list(545)> 12 Years a Slave (film), 1961 Major League Ba...
#   modified: <dict(2)> page, wikidata
#   pageid: 11055577
#   parsetree: <str(63717)> <root><template><title>Use mdy dates</ti...
#   random: No Surprise (Daughtry song)
#   redirects: <list(2)> {'pageid': 43613175, 'ns': 0, 'title': 'Boy...
#   requests: <list(8)> query, query, parse, wikidata, labels, label...
#   title: Boyhood_(film)
#   url: https://en.wikipedia.org/wiki/Boyhood_(film)
#   url_raw: https://en.wikipedia.org/wiki/Boyhood_(film)?action=raw
#   watchers: 133
#   what: film
#   wikibase: Q4103201
#   wikidata: <dict(63)> IMDb ID (P345), instance of (P31), director...
#   wikidata_pageid: 3911164
#   wikidata_url: https://www.wikidata.org/wiki/Q4103201
#   wikitext: <str(51477)> {{Use mdy dates|date=March 2015}}{{Infobo...
# }
# https://upload.wikimedia.org/wikipedia/en/a/a6/Boyhood_%282014%29.png
# 16
# Casablanca_(film)
# en.wikipedia.org (query) Casablanca_(film)
# en.wikipedia.org (query) Casablanca (film) (&plcontinue=57585|0|T...
# en.wikipedia.org (parse) 57585
# www.wikidata.org (wikidata) Q132689
# www.wikidata.org (labels) P910|P1431|Q20644795|Q1819392|Q2831802|...
# www.wikidata.org (labels) Q22752868|Q838368|P5099|Q70692|P86|P147...
# www.wikidata.org (labels) P227|P18|P166|Q93467|Q5563216|P3138|P25...
# www.wikidata.org (labels) P1411|P2509|Q1383202|Q318734|Q3101520|Q...
# en.wikipedia.org (restbase) /page/summary/Casablanca_(film)
# en.wikipedia.org (imageinfo) File:CasablancaPoster-Gold.jpg|File:...
# Casablanca (film) (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(7)> United States, California, Wikipedia 1.0,...
#   claims: <dict(89)> P373, P57, P162, P161, P344, P272, P345, P364...
#   description: 1942 film by Michael Curtiz
#   exhtml: <str(631)> <p><i><b>Casablanca</b></i> is a 1942 America...
#   exrest: <str(603)> Casablanca is a 1942 American romantic drama ...
#   extext: <str(2210)> _**Casablanca**_ is a 1942 American romantic...
#   extract: <str(2327)> <p class="mw-empty-elt"></p><p><i><b>Casabl...
#   image: <list(8)> {'kind': 'query-pageimage', 'file': 'File:Casab...
#   infobox: <dict(21)> name, image, image_size, alt, caption, direc...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/category:C...
#   label: Casablanca
#   labels: <dict(170)> P910, P1431, Q20644795, Q1819392, Q2831802, ...
#   length: 99,809
#   links: <list(628)> 12 Years a Slave (film), 16th Academy Awards,...
#   modified: <dict(2)> page, wikidata
#   pageid: 57585
#   parsetree: <str(123924)> <root><template><title>short descriptio...
#   random: Eygurande-et-Gardedeuil
#   redirects: <list(19)> {'pageid': 46343, 'ns': 0, 'title': 'Richa...
#   requests: <list(10)> query, query, parse, wikidata, labels, labe...
#   title: Casablanca_(film)
#   url: https://en.wikipedia.org/wiki/Casablanca_(film)
#   url_raw: https://en.wikipedia.org/wiki/Casablanca_(film)?action=raw
#   watchers: 303
#   what: film
#   wikibase: Q132689
#   wikidata: <dict(89)> Commons category (P373), director (P57), pr...
#   wikidata_pageid: 134475
#   wikidata_url: https://www.wikidata.org/wiki/Q132689
#   wikitext: <str(99240)> {{short description|1942 film by Michael ...
# }
# https://upload.wikimedia.org/wikipedia/commons/b/b3/CasablancaPoster-Gold.jpg
# 17
# Moonlight_(2016_film)
# en.wikipedia.org (query) Moonlight_(2016_film)
# en.wikipedia.org (parse) 48320630
# www.wikidata.org (wikidata) Q21527875
# www.wikidata.org (labels) P1431|Q106301|P4947|P2631|Q130232|Q2330...
# www.wikidata.org (labels) P1191|P344|P3145|Q28980118|P3135|Q15658...
# www.wikidata.org (labels) P1981|P4276|P2013|Q11424|P2629|P58|P268...
# www.wikidata.org (labels) P495|P2508|P3808
# en.wikipedia.org (restbase) /page/summary/Moonlight_(2016_film)
# en.wikipedia.org (imageinfo) File:Moonlight (2016 film).png
# Moonlight (2016 film) (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(5)> United States, LGBT studies, Film, Africa...
#   claims: <dict(90)> P31, P364, P345, P1476, P577, P57, P161, P495...
#   description: 2016 film by Barry Jenkins
#   exhtml: <str(350)> <p><i><b>Moonlight</b></i> is a 2016 American...
#   exrest: <str(322)> Moonlight is a 2016 American coming-of-age dr...
#   extext: <str(1628)> _**Moonlight**_ is a 2016 American coming-of...
#   extract: <str(1771)> <p class="mw-empty-elt"></p><p><span id="po...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Moonlight...
#   infobox: <dict(20)> name, image, caption, director, producers, s...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Moonlight_...
#   label: Moonlight
#   labels: <dict(153)> P1431, Q106301, P4947, P2631, Q130232, Q2330...
#   length: 69,253
#   links: <list(467)> 12 Years a Slave (film), 2016 Toronto Interna...
#   modified: <dict(2)> page, wikidata
#   pageid: 48320630
#   parsetree: <str(89730)> <root><template><title>short description...
#   random: Charley Harraway
#   redirects: <list(6)> {'pageid': 52266718, 'ns': 0, 'title': 'Chi...
#   requests: <list(9)> query, parse, wikidata, labels, labels, labe...
#   title: Moonlight_(2016_film)
#   url: https://en.wikipedia.org/wiki/Moonlight_(2016_film)
#   url_raw: https://en.wikipedia.org/wiki/Moonlight_(2016_film)?act...
#   watchers: 98
#   what: film
#   wikibase: Q21527875
#   wikidata: <dict(90)> instance of (P31), original language of fil...
#   wikidata_pageid: 23571412
#   wikidata_url: https://www.wikidata.org/wiki/Q21527875
#   wikitext: <str(68789)> {{short description|2016 film by Barry Je...
# }
# https://upload.wikimedia.org/wikipedia/en/8/84/Moonlight_%282016_film%29.png
# 18
# Psycho_(1960_film)
# en.wikipedia.org (query) Psycho_(1960_film)
# en.wikipedia.org (parse) 23880
# www.wikidata.org (wikidata) Q163038
# www.wikidata.org (labels) P910|P2747|Q106301|P4947|P2631|P3212|P7...
# www.wikidata.org (labels) P162|P268|P344|Q1275361|P2638|P4282|P57...
# www.wikidata.org (labels) Q7374|P4276|P3995|Q11424|P144|P58|Q1200...
# en.wikipedia.org (restbase) /page/summary/Psycho_(1960_film)
# en.wikipedia.org (imageinfo) File:Psycho (1960).jpg
# Psycho (1960 film) (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(6)> United States, California, Film, Horror, ...
#   claims: <dict(93)> P57, P162, P161, P345, P58, P144, P373, P480,...
#   description: 1960 horror film by Alfred Hitchcock
#   exhtml: <str(516)> <p><i><b>Psycho</b></i> is a 1960 American ps...
#   exrest: <str(495)> Psycho is a 1960 American psychological horro...
#   extext: <str(1640)> _**Psycho**_ is a 1960 American psychologica...
#   extract: <str(1737)> <p class="mw-empty-elt"></p><p><i><b>Psycho...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Psycho (1...
#   infobox: <dict(20)> name, image, alt, caption, director, produce...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:P...
#   label: Psycho
#   labels: <dict(146)> P910, P2747, Q106301, P4947, P2631, P3212, P...
#   length: 103,219
#   links: <list(400)> 18th Golden Globe Awards, 33rd Academy Awards...
#   modified: <dict(2)> page, wikidata
#   pageid: 23880
#   parsetree: <str(137578)> <root><template><title>short descriptio...
#   random: Pam Zekman
#   redirects: <list(9)> {'pageid': 14830856, 'ns': 0, 'title': "Alf...
#   requests: <list(8)> query, parse, wikidata, labels, labels, labe...
#   title: Psycho_(1960_film)
#   url: https://en.wikipedia.org/wiki/Psycho_(1960_film)
#   url_raw: https://en.wikipedia.org/wiki/Psycho_(1960_film)?action=raw
#   watchers: 262
#   what: film
#   wikibase: Q163038
#   wikidata: <dict(93)> director (P57), producer (P162), cast membe...
#   wikidata_pageid: 163834
#   wikidata_url: https://www.wikidata.org/wiki/Q163038
#   wikitext: <str(102599)> {{short description|1960 horror film by ...
# }
# https://upload.wikimedia.org/wikipedia/en/b/b9/Psycho_%281960%29.jpg
# 19
# Laura_(1944_film)
# en.wikipedia.org (query) Laura_(1944_film)
# en.wikipedia.org (parse) 74871
# www.wikidata.org (wikidata) Q976149
# www.wikidata.org (labels) Q1645179|Q348093|P910|Q3568616|P4947|P2...
# www.wikidata.org (labels) P1552|P345|Q45171911|Q107258|P1237|P463...
# www.wikidata.org (labels) Q103360|P6145|Q823422|P2603|P3107|Q2225...
# en.wikipedia.org (restbase) /page/summary/Laura_(1944_film)
# en.wikipedia.org (imageinfo) File:Laura23234.jpg|File:Gene Tierne...
# Laura (1944 film) (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(1)> '' Laura ''
#   assessments: <dict(3)> United States, Film, Library of Congress
#   claims: <dict(72)> P31, P345, P57, P58, P161, P144, P364, P162, ...
#   description: 1944 American film noir directed by Otto Preminger
#   exhtml: <str(322)> <p><i><b>Laura</b></i> is a 1944 American fil...
#   exrest: <str(294)> Laura is a 1944 American film noir produced a...
#   extext: <str(621)> _**Laura**_ is a 1944 American film noir prod...
#   extract: <str(689)> <p class="mw-empty-elt"></p><p><i><b>Laura</...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:Laura2323...
#   infobox: <dict(18)> name, image, caption, director, producer, sc...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Laura_(194...
#   label: Laura
#   labels: <dict(121)> Q1645179, Q348093, P910, Q3568616, P4947, P2...
#   length: 25,290
#   links: <list(166)> 20th Century Fox, 20th Century Fox Home Enter...
#   modified: <dict(2)> page, wikidata
#   pageid: 74871
#   parsetree: <str(31452)> <root><template><title>Use mdy dates</ti...
#   random: Kul Tepe
#   redirects: <list(4)> {'pageid': 2114094, 'ns': 0, 'title': 'Laur...
#   requests: <list(8)> query, parse, wikidata, labels, labels, labe...
#   title: Laura_(1944_film)
#   url: https://en.wikipedia.org/wiki/Laura_(1944_film)
#   url_raw: https://en.wikipedia.org/wiki/Laura_(1944_film)?action=raw
#   watchers: 53
#   what: film
#   wikibase: Q976149
#   wikidata: <dict(72)> instance of (P31), IMDb ID (P345), director...
#   wikidata_pageid: 925829
#   wikidata_url: https://www.wikidata.org/wiki/Q976149
#   wikitext: <str(25022)> {{Use mdy dates|date=December 2018}}{{Inf...
# }
# https://upload.wikimedia.org/wikipedia/en/d/d6/Laura23234.jpg
# 20
# Nosferatu
# en.wikipedia.org (query) Nosferatu
# en.wikipedia.org (parse) 82423
# www.wikidata.org (wikidata) Q151895
# www.wikidata.org (labels) P910|Q2177665|P5338|Q1442062|P4947|P263...
# www.wikidata.org (labels) Q36184|P1562|Q1599343|P3302|P1552|P345|...
# www.wikidata.org (labels) P2518|Q2137852|Q77757|P4665|Q89241|P260...
# en.wikipedia.org (restbase) /page/summary/Nosferatu
# en.wikipedia.org (imageinfo) File:Slovakia Oravsky Podzamok.jpg|F...
# Nosferatu (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(3)> Film, Germany, Horror
#   claims: <dict(77)> P724, P345, P373, P31, P57, P58, P144, P480, ...
#   description: 1922 film directed by F. W. Murnau
#   exhtml: <str(485)> <p><i><b><i lang="de" title="German language ...
#   exrest: <str(411)> Nosferatu, eine Symphonie des Grauens is a 19...
#   extext: <str(834)> _**_Nosferatu, eine Symphonie des Grauens_**_...
#   extract: <str(969)> <p class="mw-empty-elt"></p><p><i><b><i lang...
#   image: <list(6)> {'kind': 'query-pageimage', 'file': 'File:Nosfe...
#   infobox: <dict(16)> name, image, caption, director, producer, sc...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:N...
#   label: Nosferatu
#   labels: <dict(120)> P910, Q2177665, P5338, Q1442062, P4947, P263...
#   length: 33,228
#   links: <list(369)> 4 Devils, A. O. Scott, Abbott and Costello Me...
#   modified: <dict(2)> page, wikidata
#   pageid: 82423
#   parsetree: <str(44043)> <root><template><title>Redirect</title><...
#   random: Paradox, Colorado
#   redirects: <list(21)> {'pageid': 510914, 'ns': 0, 'title': 'A Sy...
#   requests: <list(8)> query, parse, wikidata, labels, labels, labe...
#   title: Nosferatu
#   url: https://en.wikipedia.org/wiki/Nosferatu
#   url_raw: https://en.wikipedia.org/wiki/Nosferatu?action=raw
#   watchers: 234
#   what: silent film
#   wikibase: Q151895
#   wikidata: <dict(77)> Internet Archive ID (P724), IMDb ID (P345),...
#   wikidata_pageid: 153292
#   wikidata_url: https://www.wikidata.org/wiki/Q151895
#   wikitext: <str(32993)> {{Redirect|Nosferatu the Vampire |the 197...
# }
# https://upload.wikimedia.org/wikipedia/en/9/92/Nosferatuposter.jpg
# 21
# Snow_White_and_the_Seven_Dwarfs_(1937_film)
# en.wikipedia.org (query) Snow_White_and_the_Seven_Dwarfs_(1937_film)
# en.wikipedia.org (parse) 76361
# www.wikidata.org (wikidata) Q134430
# www.wikidata.org (labels) Q703588|Q3110380|Q2420722|P2747|Q693256...
# www.wikidata.org (labels) Q2977202|Q214045|Q1368756|Q3303696|P10|...
# www.wikidata.org (labels) P793|P3302|P1552|P345|Q45171911|Q306858...
# www.wikidata.org (labels) P2529|Q29061014|Q842256|Q11831|Q3306605...
# www.wikidata.org (labels) P161|Q3436361|P747|Q3517047|P4786|Q3432...
# en.wikipedia.org (restbase) /page/summary/Snow_White_and_the_Seve...
# en.wikipedia.org (imageinfo) File:Snow White 1937 poster.png|File...
# Snow White and the Seven Dwarfs (1937 film) (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(2)> Snow White and the 7 Dwarfs, Snow White and t...
#   assessments: <dict(5)> United States, Film, Animation, Library o...
#   claims: <dict(91)> P144, P373, P345, P31, P57, P58, P162, P272, ...
#   description: <str(63)> 1937 American animated film produced by W...
#   exhtml: <str(674)> <p><i><b>Snow White and the Seven Dwarfs</b><...
#   exrest: <str(653)> Snow White and the Seven Dwarfs is a 1937 Ame...
#   extext: <str(1973)> _**Snow White and the Seven Dwarfs**_ is a 1...
#   extract: <str(2072)> <p class="mw-empty-elt"></p><p><i><b>Snow W...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:Snow Whit...
#   infobox: <dict(17)> name, image, caption, writer, based on, dire...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:S...
#   label: Snow White and the Seven Dwarfs
#   labels: <dict(231)> Q703588, Q3110380, Q2420722, P2747, Q693256,...
#   length: 68,641
#   links: <list(472)> 11th Academy Awards, 12 basic principles of a...
#   modified: <dict(2)> page, wikidata
#   pageid: 76361
#   parsetree: <str(85259)> <root><template><title>for</title><part>...
#   random: Niamina Dankunku
#   redirects: <list(13)> {'pageid': 265931, 'ns': 0, 'title': "Walt...
#   requests: <list(10)> query, parse, wikidata, labels, labels, lab...
#   title: Snow_White_and_the_Seven_Dwarfs_(1937_film)
#   url: <str(73)> https://en.wikipedia.org/wiki/Snow_White_and_the_...
#   url_raw: <str(84)> https://en.wikipedia.org/wiki/Snow_White_and_...
#   watchers: 249
#   what: animated feature film
#   wikibase: Q134430
#   wikidata: <dict(91)> based on (P144), Commons category (P373), I...
#   wikidata_pageid: 136176
#   wikidata_url: https://www.wikidata.org/wiki/Q134430
#   wikitext: <str(68248)> {{for|the Disney franchise|Snow White (fr...
# }
# https://upload.wikimedia.org/wikipedia/en/4/49/Snow_White_1937_poster.png
# 22
# A_Hard_Day%27s_Night_(film)
# en.wikipedia.org (query) A_Hard_Day's_Night_(film)
# en.wikipedia.org (parse) A_Hard_Day's_Night_(film)
# API error: {'code': 'invalidtitle', 'info': 'Bad title "A_Hard_Day%27s_Night_(film)".', 'docref': 'See https://en.wikipedia.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}
# en.wikipedia.org (query) La_Grande_Illusion
# ...
#   title: Harry_Potter_and_the_Deathly_Hallows_–_Part_2
#   url: <str(75)> https://en.wikipedia.org/wiki/Harry_Potter_and_th...
#   url_raw: <str(86)> https://en.wikipedia.org/wiki/Harry_Potter_an...
#   watchers: 238
#   what: 3D film
#   wikibase: Q232009
#   wikidata: <dict(91)> director (P57), instance of (P31), producer...
#   wikidata_pageid: 225835
#   wikidata_url: https://www.wikidata.org/wiki/Q232009
#   wikitext: <str(88727)> {{Good article}}{{EngvarB|date=June 2014}...
# }
# https://upload.wikimedia.org/wikipedia/en/d/df/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2.jpg
# 94
# The_Grapes_of_Wrath_(film)
# en.wikipedia.org (query) The_Grapes_of_Wrath_(film)
# en.wikipedia.org (query) The Grapes of Wrath (film) (&plcontinue=...
# en.wikipedia.org (parse) 4350811
# www.wikidata.org (wikidata) Q676039
# www.wikidata.org (labels) Q1566398|Q2412911|Q3109650|Q106301|P494...
# www.wikidata.org (labels) P2554|P577|Q3368537|Q920018|P3141|Q1599...
# www.wikidata.org (labels) Q5336701|Q20644796|P1981|P4276|Q11424|Q...
# en.wikipedia.org (restbase) /page/summary/The_Grapes_of_Wrath_(film)
# en.wikipedia.org (imageinfo) File:Grapes of Wrath, The - (Origina...
# The Grapes of Wrath (film) (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(1)> Grapes of Wrath
#   assessments: <dict(4)> United States, Film, Library of Congress,...
#   claims: <dict(74)> P31, P57, P345, P373, P161, P144, P364, P480,...
#   description: 1940 film by John Ford
#   exhtml: <str(274)> <p><i><b>The Grapes of Wrath</b></i> is a 194...
#   exrest: <str(253)> The Grapes of Wrath is a 1940 American drama ...
#   extext: <str(892)> _**The Grapes of Wrath**_ is a 1940 American ...
#   extract: <str(931)> <p><i><b>The Grapes of Wrath</b></i> is a 19...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:Wrathpost...
#   infobox: <dict(18)> name, image, caption, director, producer, sc...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:T...
#   label: The Grapes of Wrath
#   labels: <dict(143)> Q1566398, Q2412911, Q3109650, Q106301, P4947...
#   length: 26,619
#   links: <list(662)> 20,000 Years in Sing Sing, 20th Century Fox, ...
#   modified: <dict(2)> page, wikidata
#   pageid: 4350811
#   parsetree: <str(31788)> <root><template><title>For</title><part>...
#   random: Mill Hill (disambiguation)
#   requests: <list(9)> query, query, parse, wikidata, labels, label...
#   title: The_Grapes_of_Wrath_(film)
#   url: https://en.wikipedia.org/wiki/The_Grapes_of_Wrath_(film)
#   url_raw: <str(67)> https://en.wikipedia.org/wiki/The_Grapes_of_W...
#   watchers: 58
#   what: film
#   wikibase: Q676039
#   wikidata: <dict(74)> instance of (P31), director (P57), IMDb ID ...
#   wikidata_pageid: 636811
#   wikidata_url: https://www.wikidata.org/wiki/Q676039
#   wikitext: <str(26325)> {{For|the 1990 Broadway play|The Grapes o...
# }
# https://upload.wikimedia.org/wikipedia/en/9/9f/Wrathposters141.jpg
# 95
# Roman_Holiday
# en.wikipedia.org (query) Roman_Holiday
# en.wikipedia.org (parse) 76310
# www.wikidata.org (wikidata) Q201293
# www.wikidata.org (labels) Q84650|Q1936098|Q20644795|Q3773514|Q154...
# www.wikidata.org (labels) P2638|P3145|P5786|P3135|Q3541979|P1562|...
# www.wikidata.org (labels) P2518|Q2158920|Q1655589|Q159846|Q219951...
# en.wikipedia.org (restbase) /page/summary/Roman_Holiday
# en.wikipedia.org (imageinfo) File:Roman Holiday poster.png|File:A...
# Roman Holiday (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(1)> '' Roman Holiday ''
#   assessments: <dict(3)> United States, Film, Library of Congress
#   claims: <dict(77)> P373, P345, P31, P58, P161, P57, P480, P272, ...
#   description: 1953 American romantic comedy directed by William Wyler
#   exhtml: <str(328)> <p><i><b>Roman Holiday</b></i> is a 1953 Amer...
#   exrest: <str(307)> Roman Holiday is a 1953 American romantic com...
#   extext: <str(1092)> _**Roman Holiday**_ is a 1953 American roman...
#   extract: <str(1146)> <p><i><b>Roman Holiday</b></i> is a 1953 Am...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:Roman Hol...
#   infobox: <dict(18)> name, image, caption, director, producer, sc...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:R...
#   label: Roman Holiday
#   labels: <dict(129)> Q84650, Q1936098, Q20644795, Q3773514, Q1542...
#   length: 18,861
#   links: <list(150)> A House Divided (1931 film), AFI's 10 Top 10,...
#   modified: <dict(2)> page, wikidata
#   pageid: 76310
#   parsetree: <str(22932)> <root><template><title>About</title><par...
#   random: Dahlia Wasfi
#   redirects: <list(3)> {'pageid': 9450357, 'ns': 0, 'title': 'Roma...
#   requests: <list(8)> query, parse, wikidata, labels, labels, labe...
#   title: Roman_Holiday
#   url: https://en.wikipedia.org/wiki/Roman_Holiday
#   url_raw: https://en.wikipedia.org/wiki/Roman_Holiday?action=raw
#   watchers: 89
#   what: film
#   wikibase: Q201293
#   wikidata: <dict(77)> Commons category (P373), IMDb ID (P345), in...
#   wikidata_pageid: 197962
#   wikidata_url: https://www.wikidata.org/wiki/Q201293
#   wikitext: <str(18619)> {{About|the film|other uses}}{{Infobox fi...
# }
# https://upload.wikimedia.org/wikipedia/en/e/ec/Roman_Holiday_poster.png
# 96
# Man_on_Wire
# en.wikipedia.org (query) Man_on_Wire
# en.wikipedia.org (parse) 15526709
# www.wikidata.org (wikidata) Q1417721
# www.wikidata.org (labels) Q20644795|P2747|P4947|P2631|P3212|P750|...
# www.wikidata.org (labels) Q93204|P3593|Q150|P1970|P227|P166|P3138...
# en.wikipedia.org (restbase) /page/summary/Man_on_Wire
# en.wikipedia.org (imageinfo) File:Man on wire ver2.jpg
# Man on Wire (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(2)> United States, Film
#   claims: <dict(66)> P345, P31, P57, P161, P495, P136, P856, P646,...
#   description: 2008 documentary film directed by James Marsh
#   exhtml: <str(767)> <p><i><b>Man on Wire</b></i> is a 2008 Britis...
#   exrest: <str(732)> Man on Wire is a 2008 British-American biogra...
#   extext: <str(1154)> _**Man on Wire**_ is a 2008 British-American...
#   extract: <str(1231)> <p class="mw-empty-elt"></p><p><i><b>Man on...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Man on wi...
#   infobox: <dict(17)> name, image, caption, director, producer, st...
#   label: Man on Wire
#   labels: <dict(86)> Q20644795, P2747, P4947, P2631, P3212, P750, ...
#   length: 18,183
#   links: <list(263)> 20 Feet from Stardom, 2008 Sundance Film Fest...
#   modified: <dict(2)> page, wikidata
#   pageid: 15526709
#   parsetree: <str(25374)> <root><template><title>about</title><par...
#   random: Danger! (short story)
#   redirects: <list(4)> {'pageid': 15602927, 'ns': 0, 'title': 'Man...
#   requests: <list(7)> query, parse, wikidata, labels, labels, rest...
#   title: Man_on_Wire
#   url: https://en.wikipedia.org/wiki/Man_on_Wire
#   url_raw: https://en.wikipedia.org/wiki/Man_on_Wire?action=raw
#   watchers: 52
#   what: film
#   wikibase: Q1417721
#   wikidata: <dict(66)> IMDb ID (P345), instance of (P31), director...
#   wikidata_pageid: 1356471
#   wikidata_url: https://www.wikidata.org/wiki/Q1417721
#   wikitext: <str(17880)> {{about|the film|the album by PNC|Man on ...
# }
# https://upload.wikimedia.org/wikipedia/en/5/54/Man_on_wire_ver2.jpg
# 97
# Jaws_(film)
# en.wikipedia.org (query) Jaws_(film)
# en.wikipedia.org (query) Jaws (film) (&plcontinue=74830|100|1970s)
# en.wikipedia.org (parse) 74830
# www.wikidata.org (wikidata) Q189505
# www.wikidata.org (labels) Q978706|Q7372|P4947|P2631|P3212|P750|P1...
# www.wikidata.org (labels) P4783|P577|P3141|Q1691324|P162|P344|P26...
# www.wikidata.org (labels) Q11424|Q377616|Q414574|Q6166233|P144|Q1...
# en.wikipedia.org (restbase) /page/summary/Jaws_(film)
# en.wikipedia.org (imageinfo) File:Jaws-logo.svg|File:JAWS Movie p...
# Jaws (film) (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(7)> United States, California, Wikipedia 1.0,...
#   claims: <dict(98)> P31, P345, P57, P144, P373, P58, P480, P162, ...
#   description: 1975 American horror film directed by Steven Spielberg
#   exhtml: <str(619)> <p><i><b>Jaws</b></i> is a 1975 American thri...
#   exrest: <str(598)> Jaws is a 1975 American thriller film directe...
#   extext: <str(2206)> _**Jaws**_ is a 1975 American thriller film ...
#   extract: <str(2306)> <p class="mw-empty-elt"></p><p><i><b>Jaws</...
#   image: <list(4)> {'kind': 'parse-image', 'file': 'File:JAWS Movi...
#   infobox: <dict(20)> name, image, alt, caption, director, produce...
#   iwlinks: <list(1)> https://en.wikiquote.org/wiki/Jaws_(film)
#   label: Jaws
#   labels: <dict(142)> Q978706, Q7372, P4947, P2631, P3212, P750, P...
#   length: 125,124
#   links: <list(485)> 1941 (film), 20,000 Leagues Under the Sea (19...
#   modified: <dict(2)> page, wikidata
#   pageid: 74830
#   parsetree: <str(179158)> <root><template><title>Use mdy dates</t...
#   random: The Philly Kid
#   redirects: <list(15)> {'pageid': 2116029, 'ns': 0, 'title': 'Ami...
#   requests: <list(9)> query, query, parse, wikidata, labels, label...
#   title: Jaws_(film)
#   url: https://en.wikipedia.org/wiki/Jaws_(film)
#   url_raw: https://en.wikipedia.org/wiki/Jaws_(film)?action=raw
#   watchers: 288
#   what: film
#   wikibase: Q189505
#   wikidata: <dict(98)> instance of (P31), IMDb ID (P345), director...
#   wikidata_pageid: 188031
#   wikidata_url: https://www.wikidata.org/wiki/Q189505
#   wikitext: <str(124621)> {{Use mdy dates|date=October 2015}}{{Inf...
# }
# https://upload.wikimedia.org/wikipedia/en/e/eb/JAWS_Movie_poster.jpg
# 98
# Toy_Story
# en.wikipedia.org (query) Toy_Story
# en.wikipedia.org (query) Toy Story (&plcontinue=53085|11|Joss_Whedon)
# en.wikipedia.org (parse) 53085
# www.wikidata.org (wikidata) Q171048
# www.wikidata.org (labels) P910|P1431|Q1097348|P2747|P4947|P2631|P...
# www.wikidata.org (labels) P162|P5905|Q663106|P2638|P5786|P4282|P1...
# www.wikidata.org (labels) Q2263|P571|P2465|Q22101947|Q208408|Q339...
# en.wikipedia.org (restbase) /page/summary/Toy_Story
# en.wikipedia.org (imageinfo) File:Toy Story.jpg
# Toy Story (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(7)> United States, Film, Toys, Animation, Com...
#   claims: <dict(90)> P57, P162, P272, P345, P31, P58, P373, P480, ...
#   description: 1995 American animated film directed by John Lasseter
#   exhtml: <str(1178)> <p><i><b>Toy Story</b></i> is a 1995 America...
#   exrest: <str(1157)> Toy Story is a 1995 American computer-animat...
#   extext: <str(3113)> _**Toy Story**_ is a 1995 American computer-...
#   extract: <str(3235)> <p class="mw-empty-elt"></p><p><i><b>Toy St...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Toy Story...
#   infobox: <dict(19)> name, image, alt, caption, director, produce...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:T...
#   label: Toy Story
#   labels: <dict(136)> P910, P1431, Q1097348, P2747, P4947, P2631, ...
#   length: 111,190
#   links: <list(489)> 48 Hrs., 60th Academy Awards, A Bug's Life, A...
#   modified: <dict(2)> page, wikidata
#   pageid: 53085
#   parsetree: <str(147727)> <root><template><title>short descriptio...
#   random: Arthur William Crawley Boevey
#   redirects: <list(13)> {'pageid': 426429, 'ns': 0, 'title': 'ToyS...
#   requests: <list(9)> query, query, parse, wikidata, labels, label...
#   title: Toy_Story
#   url: https://en.wikipedia.org/wiki/Toy_Story
#   url_raw: https://en.wikipedia.org/wiki/Toy_Story?action=raw
#   watchers: 327
#   what: animated feature film
#   wikibase: Q171048
#   wikidata: <dict(90)> director (P57), producer (P162), production...
#   wikidata_pageid: 171266
#   wikidata_url: https://www.wikidata.org/wiki/Q171048
#   wikitext: <str(110738)> {{short description|1995 American animat...
# }
# https://upload.wikimedia.org/wikipedia/en/1/13/Toy_Story.jpg
# 99
# The_Godfather_Part_II
# en.wikipedia.org (query) The_Godfather_Part_II
# en.wikipedia.org (parse) 73875
# www.wikidata.org (wikidata) Q184768
# www.wikidata.org (labels) Q106301|Q95043|P2631|Q130232|P3212|P494...
# www.wikidata.org (labels) Q102642|Q3885536|Q3388862|P1476|P2554|Q...
# www.wikidata.org (labels) Q297945|P1970|Q83694|Q277751|P166|Q2223...
# www.wikidata.org (labels) P3933|P1411|Q2074570|P2509|Q245808|Q193...
# en.wikipedia.org (restbase) /page/summary/The_Godfather_Part_II
# en.wikipedia.org (imageinfo) File:Godfather part ii.jpg
# The Godfather Part II (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(1)> Godfather Part II
#   assessments: <dict(4)> United States, Film, Library of Congress,...
#   claims: <dict(81)> P345, P179, P31, P57, P58, P161, P144, P480, ...
#   description: 1974 film directed by Francis Ford Coppola
#   exhtml: <str(692)> <p><i><b>The Godfather Part II</b></i> is a 1...
#   exrest: <str(657)> The Godfather Part II is a 1974 American crim...
#   extext: <str(1734)> _**The Godfather Part II**_ is a 1974 Americ...
#   extract: <str(1811)> <p><i><b>The Godfather Part II</b></i> is a...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Godfather...
#   infobox: <dict(19)> name, image, caption, director, producer, sc...
#   iwlinks: <list(1)> https://en.wikiquote.org/wiki/Special:Search/...
#   label: The Godfather Part II
#   labels: <dict(168)> Q106301, Q95043, P2631, Q130232, P3212, P494...
#   length: 37,595
#   links: <list(369)> 12 Years a Slave (film), 1974 in film, 29th B...
#   modified: <dict(2)> page, wikidata
#   pageid: 73875
#   parsetree: <str(45918)> <root><template><title>Infobox film</tit...
#   random: Sura (disambiguation)
#   redirects: <list(23)> {'pageid': 933519, 'ns': 0, 'title': 'The ...
#   requests: <list(9)> query, parse, wikidata, labels, labels, labe...
#   title: The_Godfather_Part_II
#   url: https://en.wikipedia.org/wiki/The_Godfather_Part_II
#   url_raw: https://en.wikipedia.org/wiki/The_Godfather_Part_II?act...
#   watchers: 208
#   what: film
#   wikibase: Q184768
#   wikidata: <dict(81)> IMDb ID (P345), part of the series (P179), ...
#   wikidata_pageid: 183705
#   wikidata_url: https://www.wikidata.org/wiki/Q184768
#   wikitext: <str(37176)> {{Infobox film| name           = The Godf...
# }
# https://upload.wikimedia.org/wikipedia/en/0/03/Godfather_part_ii.jpg
# 100
# Battleship_Potemkin
# en.wikipedia.org (query) Battleship_Potemkin
# en.wikipedia.org (query) Battleship Potemkin (&plcontinue=77865|0...
# en.wikipedia.org (parse) 77865
# www.wikidata.org (wikidata) Q152350
# www.wikidata.org (labels) P4947|P2631|P3212|P750|P1258|P480|P4780...
# www.wikidata.org (labels) P3302|P1552|P345|P4438|P4632|Q45172088|...
# www.wikidata.org (labels) P495|P2508
# en.wikipedia.org (restbase) /page/summary/Battleship_Potemkin
# en.wikipedia.org (imageinfo) File:Vintage Potemkin.jpg
# Battleship Potemkin (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(4)> Military history, Soviet Union, Russia, Film
#   claims: <dict(78)> P373, P345, P57, P480, P344, P161, P58, P162,...
#   description: 1925 film directed by Sergei Eisenstein
#   exhtml: <str(356)> <p><i><b> Battleship Potemkin</b></i>, someti...
#   exrest: <str(300)> Battleship Potemkin, sometimes rendered as  B...
#   extext: <str(553)> _**Battleship Potemkin**_ (Russian:  Бронено́...
#   extract: <str(656)> <p class="mw-empty-elt"></p><p><i><b> Battle...
#   image: <list(8)> {'kind': 'query-pageimage', 'file': 'File:Vinta...
#   infobox: <dict(16)> name, image, caption, director, producer, wr...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:T...
#   label: Battleship Potemkin
#   labels: <dict(102)> P4947, P2631, P3212, P750, P1258, P480, P478...
#   length: 44,869
#   links: <list(617)> 1905 Russian Revolution, 2001: A Space Odysse...
#   modified: <dict(2)> page, wikidata
#   pageid: 77865
#   parsetree: <str(53506)> <root><template><title>About</title><par...
#   random: Emmelie de Forest
#   redirects: <list(5)> {'pageid': 729707, 'ns': 0, 'title': 'Brone...
#   requests: <list(9)> query, query, parse, wikidata, labels, label...
#   title: Battleship_Potemkin
#   url: https://en.wikipedia.org/wiki/Battleship_Potemkin
#   url_raw: https://en.wikipedia.org/wiki/Battleship_Potemkin?action=raw
#   watchers: 145
#   what: silent film
#   wikibase: Q152350
#   wikidata: <dict(78)> Commons category (P373), IMDb ID (P345), di...
#   wikidata_pageid: 153742
#   wikidata_url: https://www.wikidata.org/wiki/Q152350
#   wikitext: <str(44241)> {{About||the real-life battleship|Russian...
# }
# https://upload.wikimedia.org/wikipedia/commons/8/85/Vintage_Potemkin.jpg

# %% [markdown]
# One you have completed the above code requirements, read and run the three cells below and interpret their output.

# %%
for key in image_errors.keys():
    print(key)
# Out:
# 22_A_Hard_Day%27s_Night_(film)
# 64_Dr._Strangelove
# 72_Rosemary%27s_Baby_(film)
# 83_Hell_or_High_Water_(film)

# %%
# Inspect unidentifiable images and download them individually
for rank_title, images in image_errors.items():
    if rank_title == '22_A_Hard_Day%27s_Night_(film)':
        url = 'https://upload.wikimedia.org/wikipedia/en/4/47/A_Hard_Days_night_movieposter.jpg'
    if rank_title == '53_12_Angry_Men_(1957_film)':
        url = 'https://upload.wikimedia.org/wikipedia/en/9/91/12_angry_men.jpg'
    if rank_title == '72_Rosemary%27s_Baby_(film)':
        url = 'https://upload.wikimedia.org/wikipedia/en/e/ef/Rosemarys_baby_poster.jpg'
    if rank_title == '93_Harry_Potter_and_the_Deathly_Hallows_–_Part_2':
        url = 'https://upload.wikimedia.org/wikipedia/en/d/df/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2.jpg'
    title = rank_title[3:]
    df_list.append({'ranking': int(title_list.index(title) + 1),
                    'title': title,
                    'poster_url': url})
    r = requests.get(url)
    # Download movie poster image
    i = Image.open(BytesIO(r.content))
    image_file_format = url.split('.')[-1]
    i.save(folder_name + "/" + rank_title + '.' + image_file_format)

# %%
# Create DataFrame from list of dictionaries
df = pd.DataFrame(df_list, columns = ['ranking', 'title', 'poster_url'])
df = df.sort_values('ranking').reset_index(drop=True)
df
# Out:
#     ranking                                          title  \
# 0         1                   The_Wizard_of_Oz_(1939_film)
# 1         2                                   Citizen_Kane
# 2         3                                  The_Third_Man
# 3         4                                 Get_Out_(film)
# 4         5                             Mad_Max:_Fury_Road
# 5         6                    The_Cabinet_of_Dr._Caligari
# 6         7                                  All_About_Eve
# 7         8                         Inside_Out_(2015_film)
# 8         9                                  The_Godfather
# 9        10                         Metropolis_(1927_film)
# 10       11                     E.T._the_Extra-Terrestrial
# 11       12                            Modern_Times_(film)
# 12       13                          It_Happened_One_Night
# 13       14                            Singin'_in_the_Rain
# 14       15                                 Boyhood_(film)
# 15       16                              Casablanca_(film)
# 16       17                          Moonlight_(2016_film)
# 17       18                             Psycho_(1960_film)
# 18       19                              Laura_(1944_film)
# 19       20                                      Nosferatu
# 20       21    Snow_White_and_the_Seven_Dwarfs_(1937_film)
# 21       22                    A_Hard_Day%27s_Night_(film)
# 22       23                             La_Grande_Illusion
# 23       24                             North_by_Northwest
# 24       25                          The_Battle_of_Algiers
# 25       26                            Dunkirk_(2017_film)
# 26       27                 The_Maltese_Falcon_(1941_film)
# 27       28                               Repulsion_(film)
# 28       29                        12_Years_a_Slave_(film)
# 29       30                            Gravity_(2013_film)
# ..      ...                                            ...
# 70       71                            Rebecca_(1940_film)
# 71       72                       Rosemary%27s_Baby_(film)
# 72       73                                   Finding_Nemo
# 73       74                                Brooklyn_(film)
# 74       75                       The_Wrestler_(2008_film)
# 75       76                       The_39_Steps_(1935_film)
# 76       77                       L.A._Confidential_(film)
# 77       78                      Gone_with_the_Wind_(film)
# 78       79                 The_Good,_the_Bad_and_the_Ugly
# 79       80                                        Skyfall
# 80       81                                Rome,_Open_City
# 81       82                                    Tokyo_Story
# 82       83                      Hell_or_High_Water_(film)
# 83       84                          Pinocchio_(1940_film)
# 84       85                    The_Jungle_Book_(2016_film)
# 85       86                              La_La_Land_(film)
# 86       87                               Star_Trek_(film)
# 87       88                                      High_Noon
# 88       89                                 Apocalypse_Now
# 89       90                              On_the_Waterfront
# 90       91                              The_Wages_of_Fear
# 91       92                          The_Last_Picture_Show
# 92       93  Harry_Potter_and_the_Deathly_Hallows_–_Part_2
# 93       94                     The_Grapes_of_Wrath_(film)
# 94       95                                  Roman_Holiday
# 95       96                                    Man_on_Wire
# 96       97                                    Jaws_(film)
# 97       98                                      Toy_Story
# 98       99                          The_Godfather_Part_II
# 99      100                            Battleship_Potemkin
#
#                                            poster_url
# 0   https://upload.wikimedia.org/wikipedia/commons...
# 1   https://upload.wikimedia.org/wikipedia/en/c/ce...
# 2   https://upload.wikimedia.org/wikipedia/en/2/21...
# 3   https://upload.wikimedia.org/wikipedia/en/a/a3...
# 4   https://upload.wikimedia.org/wikipedia/en/6/6e...
# 5   https://upload.wikimedia.org/wikipedia/commons...
# 6   https://upload.wikimedia.org/wikipedia/en/2/22...
# 7   https://upload.wikimedia.org/wikipedia/en/0/0a...
# 8   https://upload.wikimedia.org/wikipedia/en/1/1c...
# 9   https://upload.wikimedia.org/wikipedia/en/0/06...
# 10  https://upload.wikimedia.org/wikipedia/en/6/66...
# 11  https://upload.wikimedia.org/wikipedia/commons...
# 12  https://upload.wikimedia.org/wikipedia/commons...
# 13  https://upload.wikimedia.org/wikipedia/en/f/f9...
# 14  https://upload.wikimedia.org/wikipedia/en/a/a6...
# 15  https://upload.wikimedia.org/wikipedia/commons...
# 16  https://upload.wikimedia.org/wikipedia/en/8/84...
# 17  https://upload.wikimedia.org/wikipedia/en/b/b9...
# 18  https://upload.wikimedia.org/wikipedia/en/d/d6...
# 19  https://upload.wikimedia.org/wikipedia/en/9/92...
# 20  https://upload.wikimedia.org/wikipedia/en/4/49...
# 21  https://upload.wikimedia.org/wikipedia/en/4/47...
# 22  https://upload.wikimedia.org/wikipedia/en/3/33...
# 23  https://upload.wikimedia.org/wikipedia/commons...
# 24  https://upload.wikimedia.org/wikipedia/en/a/aa...
# 25  https://upload.wikimedia.org/wikipedia/en/1/15...
# 26  https://upload.wikimedia.org/wikipedia/en/9/99...
# 27  https://upload.wikimedia.org/wikipedia/en/8/89...
# 28  https://upload.wikimedia.org/wikipedia/en/5/5c...
# 29  https://upload.wikimedia.org/wikipedia/en/f/f6...
# ..                                                ...
# 70  https://upload.wikimedia.org/wikipedia/en/1/16...
# 71  https://upload.wikimedia.org/wikipedia/en/e/ef...
# 72  https://upload.wikimedia.org/wikipedia/en/2/29...
# 73  https://upload.wikimedia.org/wikipedia/en/5/5b...
# 74  https://upload.wikimedia.org/wikipedia/en/3/3e...
# 75  https://upload.wikimedia.org/wikipedia/en/9/95...
# 76  https://upload.wikimedia.org/wikipedia/en/d/d8...
# 77  https://upload.wikimedia.org/wikipedia/commons...
# 78  https://upload.wikimedia.org/wikipedia/en/4/45...
# 79  https://upload.wikimedia.org/wikipedia/en/a/a7...
# 80  https://upload.wikimedia.org/wikipedia/en/1/19...
# 81  https://upload.wikimedia.org/wikipedia/en/5/5f...
# 82  https://upload.wikimedia.org/wikipedia/en/e/ef...
# 83  https://upload.wikimedia.org/wikipedia/en/b/ba...
# 84  https://upload.wikimedia.org/wikipedia/en/a/a4...
# 85  https://upload.wikimedia.org/wikipedia/en/a/ab...
# 86  https://upload.wikimedia.org/wikipedia/en/2/29...
# 87  https://upload.wikimedia.org/wikipedia/en/5/54...
# 88  https://upload.wikimedia.org/wikipedia/en/c/c2...
# 89  https://upload.wikimedia.org/wikipedia/en/9/93...
# 90  https://upload.wikimedia.org/wikipedia/en/f/f4...
# 91  https://upload.wikimedia.org/wikipedia/en/8/8f...
# 92  https://upload.wikimedia.org/wikipedia/en/d/df...
# 93  https://upload.wikimedia.org/wikipedia/en/9/9f...
# 94  https://upload.wikimedia.org/wikipedia/en/e/ec...
# 95  https://upload.wikimedia.org/wikipedia/en/5/54...
# 96  https://upload.wikimedia.org/wikipedia/en/e/eb...
# 97  https://upload.wikimedia.org/wikipedia/en/1/13...
# 98  https://upload.wikimedia.org/wikipedia/en/0/03...
# 99  https://upload.wikimedia.org/wikipedia/commons...
#
# [100 rows x 3 columns]
